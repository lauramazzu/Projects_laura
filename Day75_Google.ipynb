# %% [markdown]
# <a href="https://colab.research.google.com/github/lauramazzu/Projects_laura/blob/main/Day75_Google.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import matplotlib.dates as mdates

# %%
df_tesla = pd.read_csv('TESLA Search Trend vs Price.csv')
df_unemployment = pd.read_csv('UE Benefits Search vs UE Rate 2004-19.csv')
df_unemployment_one = pd.read_csv('UE Benefits Search vs UE Rate 2004-20.csv')
df_bit_search = pd.read_csv('Bitcoin Search Trend.csv')
df_bit_price = pd.read_csv('Daily Bitcoin Price.csv')

df_tesla
# Out:
#           MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0    2010-06-01                3        4.766000
# 1    2010-07-01                3        3.988000
# 2    2010-08-01                2        3.896000
# 3    2010-09-01                2        4.082000
# 4    2010-10-01                2        4.368000
# ..          ...              ...             ...
# 119  2020-05-01               16      167.000000
# 120  2020-06-01               17      215.962006
# 121  2020-07-01               24      286.152008
# 122  2020-08-01               23      498.320007
# 123  2020-09-01               31      407.339996
#
# [124 rows x 3 columns]

# %%
df_unemployment_one
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0    2004-01                       9     5.7
# 1    2004-02                       8     5.6
# 2    2004-03                       7     5.8
# 3    2004-04                       8     5.6
# 4    2004-05                       6     5.6
# ..       ...                     ...     ...
# 195  2020-04                     100    14.7
# 196  2020-05                      63    13.3
# 197  2020-06                      53    11.1
# 198  2020-07                      54    10.2
# 199  2020-08                      50     8.4
#
# [200 rows x 3 columns]

# %%
df_bit_search
# Out:
#       MONTH  BTC_NEWS_SEARCH
# 0   2014-09                5
# 1   2014-10                4
# 2   2014-11                4
# 3   2014-12                4
# 4   2015-01                5
# ..      ...              ...
# 68  2020-05               22
# 69  2020-06               13
# 70  2020-07               14
# 71  2020-08               16
# 72  2020-09               13
#
# [73 rows x 2 columns]

# %%
df_bit_price
# Out:
#             DATE         CLOSE        VOLUME
# 0     2014-09-17    457.334015  2.105680e+07
# 1     2014-09-18    424.440002  3.448320e+07
# 2     2014-09-19    394.795990  3.791970e+07
# 3     2014-09-20    408.903992  3.686360e+07
# 4     2014-09-21    398.821014  2.658010e+07
# ...          ...           ...           ...
# 2199  2020-09-24  10745.548828  2.301754e+10
# 2200  2020-09-25  10702.290039  2.123255e+10
# 2201  2020-09-26  10754.437500  1.810501e+10
# 2202  2020-09-27  10774.426758  1.801688e+10
# 2203  2020-09-28  10912.536133  2.122653e+10
#
# [2204 rows x 3 columns]

# %%
df_tesla.shape
# Out:
# (124, 3)

# %%
df_unemployment.shape
# Out:
# (181, 3)

# %%
df_unemployment_one.shape
# Out:
# (200, 3)

# %%
df_bit_search.shape
# Out:
# (73, 2)

# %%
df_bit_price.shape
# Out:
# (2204, 3)

# %%
df_tesla.columns
# Out:
# Index(['MONTH', 'TSLA_WEB_SEARCH', 'TSLA_USD_CLOSE'], dtype='object')

# %%
df_unemployment.columns
# Out:
# Index(['MONTH', 'UE_BENEFITS_WEB_SEARCH', 'UNRATE'], dtype='object')

# %%
df_unemployment_one.columns
# Out:
# Index(['MONTH', 'UE_BENEFITS_WEB_SEARCH', 'UNRATE'], dtype='object')

# %%
df_bit_search.columns
# Out:
# Index(['MONTH', 'BTC_NEWS_SEARCH'], dtype='object')

# %%
df_bit_price.columns
# Out:
# Index(['DATE', 'CLOSE', 'VOLUME'], dtype='object')

# %%
df_tesla.describe()
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %%
df_unemployment.describe()
# Out:
#        UE_BENEFITS_WEB_SEARCH      UNRATE
# count              181.000000  181.000000
# mean                35.110497    6.217680
# std                 20.484925    1.891859
# min                 14.000000    3.700000
# 25%                 21.000000    4.700000
# 50%                 26.000000    5.400000
# 75%                 45.000000    7.800000
# max                100.000000   10.000000

# %%
df_unemployment_one.describe()
# Out:
#        UE_BENEFITS_WEB_SEARCH      UNRATE
# count              200.000000  200.000000
# mean                10.315000    6.173000
# std                 10.778061    2.128267
# min                  4.000000    3.500000
# 25%                  5.000000    4.600000
# 50%                  7.000000    5.400000
# 75%                 12.000000    7.825000
# max                100.000000   14.700000

# %%
df_bit_search.describe()
# Out:
#        BTC_NEWS_SEARCH
# count        73.000000
# mean         15.013699
# std          15.146959
# min           3.000000
# 25%           5.000000
# 50%          14.000000
# 75%          18.000000
# max         100.000000

# %%
df_bit_price.describe()
# Out:
#               CLOSE        VOLUME
# count   2203.000000  2.203000e+03
# mean    4429.421245  8.043622e+09
# std     4148.150071  1.176529e+10
# min      178.102997  5.914570e+06
# 25%      433.629502  6.029915e+07
# 50%     3637.520020  2.018890e+09
# 75%     7997.372803  1.322478e+10
# max    19497.400391  7.415677e+10

# %%
df_tesla.isna()
# Out:
#      MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0    False            False           False
# 1    False            False           False
# 2    False            False           False
# 3    False            False           False
# 4    False            False           False
# ..     ...              ...             ...
# 119  False            False           False
# 120  False            False           False
# 121  False            False           False
# 122  False            False           False
# 123  False            False           False
#
# [124 rows x 3 columns]

# %%
df_tesla.isna().values.any()
# Out:
# False

# %%
df_unemployment_one.isna().values.any()
# Out:
# False

# %%
df_bit_price.isna().values.any()
# Out:
# True

# %%
print(f'Missing values? for BTC price?: {df_bit_price.isna().values.sum()}')
df_bit_price[df_bit_price.CLOSE.isna()]
# Out:
# Missing values? for BTC price?: 2
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
df_bit_price.dropna(inplace = True)

# %%
df_bit_search.isna().values.any()
# Out:
# False

# %%
type(df_tesla['MONTH'][1])
# Out:
# str

# %%
df_tesla.MONTH = pd.to_datetime(df_tesla.MONTH)

# %%
df_unemployment_one.MONTH = pd.to_datetime(df_unemployment_one.MONTH)

# %%
df_bit_search.MONTH = pd.to_datetime(df_bit_search.MONTH)

# %%
df_bit_price.DATE = pd.to_datetime(df_bit_price.DATE)

# %%
df_tesla.MONTH.head()
# Out:
# 0   2010-06-01
# 1   2010-07-01
# 2   2010-08-01
# 3   2010-09-01
# 4   2010-10-01
# Name: MONTH, dtype: datetime64[ns]

# %%
#convert the daily bitcoin price to monthly data
df_bit_monthly = df_bit_price.resample('M', on = 'DATE').last()

# %%
df_bit_monthly.shape
# Out:
# (73, 2)

# %%
df_bit_monthly.head()
# Out:
#                  CLOSE      VOLUME
# DATE
# 2014-09-30  386.944000  34707300.0
# 2014-10-31  338.321014  12545400.0
# 2014-11-30  378.046997   9194440.0
# 2014-12-31  320.192993  13942900.0
# 2015-01-31  217.464005  23348200.0

# %%
df_bit_monthly.reset_index(inplace= True)
df_bit_monthly.rename(columns = {"index": "DATE"}, inplace = True)
df_bit_monthly.head()
# Out:
#         DATE       CLOSE      VOLUME
# 0 2014-09-30  386.944000  34707300.0
# 1 2014-10-31  338.321014  12545400.0
# 2 2014-11-30  378.046997   9194440.0
# 3 2014-12-31  320.192993  13942900.0
# 4 2015-01-31  217.464005  23348200.0

# %%
df_bit_search.head()
# Out:
#        MONTH  BTC_NEWS_SEARCH
# 0 2014-09-01                5
# 1 2014-10-01                4
# 2 2014-11-01                4
# 3 2014-12-01                4
# 4 2015-01-01                5

# %%
#create locators for ticks on the time axis
years= mdates.YearLocator()
months=mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')


#increases size and resolution
#this part goes always first
plt.figure(figsize=(14,8), dpi = 120)
plt.title('Tesla Web Search vs Price', fontsize = 18)

#increase fontsize and linewidth for larger charts, and rotate xaxis
#this part goes always first
plt.xticks(fontsize=14)
plt.yticks(fontsize = 14)


ax1 = plt.gca() #get the axis
ax2 = ax1.twinx() #create another axis that shares the same x-axis

#change font of secondary axis
ax2.tick_params(labelsize = 14)



# Rotating X-axis labels
for tick in ax1.get_xticklabels():
    tick.set_rotation(45)


#
#ticksax1.xaxis.set_major_locator(years)ax1.xaxis.set_major_formatter(years_fmt)ax1.xaxis.set_minor_locator(months)


ax1.set_xlabel('Year', fontsize=18)
ax1.set_ylabel('Stock Price', fontsize = 18, color = '#FF5733')
ax2.set_ylabel('Search trend', fontsize = 18, color = 'skyblue')

#Set the minimum and maximum values on the axes
ax1.set_ylim([0, 600])
ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])


ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, '#FF5733', linewidth = 3)
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, 'skyblue', linewidth =3)



#displayschart explicitly
plt.show()

# %%
#create locators for ticks on the time axis
years= mdates.YearLocator()
months=mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')


#increases size and resolution
#this part goes always first
plt.figure(figsize=(14,8), dpi = 120)
plt.title('Bitcoin News Search vs Resampled Price', fontsize = 18)

#increase fontsize and linewidth for larger charts, and rotate xaxis
#this part goes always first
plt.xticks(fontsize=14)
plt.yticks(fontsize = 14)


ax1 = plt.gca() #get the axis
ax2 = ax1.twinx() #create another axis that shares the same x-axis

#change font of secondary axis
ax2.tick_params(labelsize = 14)



# Rotating X-axis labels
for tick in ax1.get_xticklabels():
    tick.set_rotation(45)


# format the ticks
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)


ax1.set_xlabel('Year', fontsize=18)
ax1.set_ylabel('BTC price', fontsize = 18, color = '#FFB133')
ax2.set_ylabel('Search trend', fontsize = 18, color = '#489AAB')

#Set the minimum and maximum values on the axes
ax1.set_ylim([0, 14000])
ax1.set_xlim([df_bit_monthly.DATE.min(), df_bit_monthly.DATE.max()])


ax1.plot(df_bit_monthly.DATE, df_bit_monthly.CLOSE, '#FFB133', linewidth = 3,  linestyle = 'dashed')
ax2.plot(df_bit_search.MONTH, df_bit_search.BTC_NEWS_SEARCH, '#489AAB', linewidth =3, marker = 'p', markersize= 8)



#displayschart explicitly
plt.show()

# %%
df_unemployment.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                      34     5.7
# 1  2004-02                      33     5.6
# 2  2004-03                      25     5.8
# 3  2004-04                      29     5.6
# 4  2004-05                      23     5.6

# %%
#create locators for ticks on the time axis
years= mdates.YearLocator()
months=mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')


#increases size and resolution
#this part goes always first
plt.figure(figsize=(14,8), dpi = 120)
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate', fontsize = 18)
plt.grid(linestyle = '--')


#increase fontsize and linewidth for larger charts, and rotate xaxis
#this part goes always first
plt.xticks(fontsize=14)
plt.yticks(fontsize = 14)


ax1 = plt.gca() #get the axis
ax2 = ax1.twinx() #create another axis that shares the same x-axis

#change font of secondary axis
ax2.tick_params(labelsize = 14)



# Rotating X-axis labels
for tick in ax1.get_xticklabels():
    tick.set_rotation(45)


# format the ticks
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)


ax1.set_xlabel('Year', fontsize=18)
ax1.set_ylabel('FRED U/E RATE', fontsize = 18, color = '#0B5505')
ax2.set_ylabel('Search trend', fontsize = 18, color = '#4F0555')

#Set the minimum and maximum values on the axes
ax1.set_ylim([3, 10.5])
#ax1.set_xlim([df_unemployment_one.MONTH.min(), df_unemployment_one.MONTH.max()])

#calculate the rolling average over a 6month window
roll_df = df_unemployment_one[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=3).mean()




ax1.plot(df_unemployment_one.MONTH[:-24], roll_df.UNRATE[:-24], '#0B5505', linewidth = 3,  linestyle = 'dashed')
ax2.plot(df_unemployment_one.MONTH[:-24], roll_df.UE_BENEFITS_WEB_SEARCH[:-24], '#4F0555', linewidth =3)



#displayschart explicitly
plt.show()

# %%
df_unemployment_one.head()
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0 2004-01-01                       9     5.7
# 1 2004-02-01                       8     5.6
# 2 2004-03-01                       7     5.8
# 3 2004-04-01                       8     5.6
# 4 2004-05-01                       6     5.6

# %%
df_unemployment.MONTH = pd.to_datetime(df_unemployment.MONTH)

# %%
plt.figure(figsize=(14,8), dpi=120)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=45)
plt.title('Monthly US "Unemployment Benefits" Web Search vs UNRATE incl 2020', fontsize=18)

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=16)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=16)

ax1.set_xlim([df_unemployment.MONTH.min(), df_unemployment.MONTH.max()])

ax1.plot(df_unemployment.MONTH, df_unemployment.UNRATE, 'purple', linewidth=3)
ax2.plot(df_unemployment.MONTH, df_unemployment.UE_BENEFITS_WEB_SEARCH, 'skyblue', linewidth=3)

plt.show()
